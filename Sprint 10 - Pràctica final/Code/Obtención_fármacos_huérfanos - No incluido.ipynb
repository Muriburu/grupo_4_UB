# %% [markdown]
# # Tabla de medicamentos huérfanos extraida de EMEA.

# %%
import pandas as pd

df_orphan_drugs = pd.read_excel(r"C:\Users\maria\ITAcademy\Sprint 10 - Pràctica final\Data\medicines_output_orphan_designations_en.xlsx")
df_orphan_drugs = df_orphan_drugs[7:]

df_orphan_drugs.columns = df_orphan_drugs.iloc[0]  # header
df_orphan_drugs = df_orphan_drugs[1:]  # borrar la 1ª fila

#df_orphan_drugs.to_csv(r"C:\Users\maria\ITAcademy\Sprint 10 - Pràctica final\Data\df_orphan_drugs.csv", index=False)
df_orphan_drugs
# Out:
# 7    Medicine name Related EMA product number  \
# 8              NaN                        NaN
# 9              NaN                        NaN
# 10             NaN                        NaN
# 11             NaN                        NaN
# 12             NaN                        NaN
# ...            ...                        ...
# 3064           NaN                        NaN
# 3065           NaN                        NaN
# 3066           NaN                        NaN
# 3067     Prohippur            EMEA/H/C/004150
# 3068           NaN                        NaN
#
# 7                                      Active substance  \
# 8                                         Rilzabrutinib
# 9                                           Clofutriben
# 10                                           xevinapant
# 11    Adeno-associated virus serotype 5 vector encod...
# 12    Autologous CD34+ cells transfected with lentiv...
# ...                                                 ...
# ...

# %% [markdown]
# - Falta limpiar bien el df.
# - Se podría buscar un dataset que nos permita relacionar los medicamentos huérfanos con las enfermedades (En Kaggle hay uno: https://www.kaggle.com/datasets/rajendarreddie/fda-orphan-drugs-data)
